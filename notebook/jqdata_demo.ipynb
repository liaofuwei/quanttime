# %%
from jqdatasdk import *
import pandas as pd
import os
from datetime import datetime,timedelta

# %%
#授权
auth('13811866763',"sam155")
# Out:
# auth success  ( 如需说明文档请查看：https://url.cn/5oB7EOO，更多问题请联系JQData管理员，微信号：JQData02 )

# %%
#券商的行业编码是J67
security_code = get_industry_stocks('J67')
#银行J66
bank_code = get_industry_stocks('J66')
bank_code
# Out:
# ['000001.XSHE',
#  '002142.XSHE',
#  '002807.XSHE',
#  '002839.XSHE',
#  '002936.XSHE',
#  '002948.XSHE',
#  '002958.XSHE',
#  '600000.XSHG',
#  '600015.XSHG',
#  '600016.XSHG',
#  '600036.XSHG',
#  '600901.XSHG',
#  '600908.XSHG',
#  '600919.XSHG',
#  '600926.XSHG',
#  '600928.XSHG',
#  '601009.XSHG',
#  '601128.XSHG',
#  '601166.XSHG',
#  '601169.XSHG',
#  '601229.XSHG',
#  '601288.XSHG',
#  '601328.XSHG',
#  '601398.XSHG',
#  '601577.XSHG',
#  '601818.XSHG',
#  '601838.XSHG',
#  '601860.XSHG',
#  '601939.XSHG',
#  '601988.XSHG',
#  '601997.XSHG',
#  '601998.XSHG',
#  '603323.XSHG']

# %%
#券商财经数据所在目录
data_dir = "C:\\quanttime\\data\\security_raw\\"
filelist = os.listdir(data_dir)
for code in security_code:
    filepath = data_dir + code + ".csv"
    filename = code + ".csv"
    if filename not in filelist:
        continue
    security = pd.read_csv(filepath)
    #print (security)
    #获取已下载数据的最后时间日期，该日期的下两天作为更新日期的开始，下一天作为初始日期取第一次数据
    enddate = security['day'].iloc[-1]
    if '/' in enddate:
        startdate = datetime.strptime(security['day'].iloc[-1],"%Y/%m/%d") + timedelta(days=2)
        initialdate = datetime.strptime(security['day'].iloc[-1],"%Y/%m/%d") + timedelta(days=1)
        print (startdate)
    elif '-' in enddate:
        startdate = datetime.strptime(security['day'].iloc[-1],"%Y-%m-%d") + timedelta(days=2)
        initialdate = datetime.strptime(security['day'].iloc[-1],"%Y-%m-%d") + timedelta(days=1)
        print (startdate)
    else:
        print (code)
    
    startdata = startdate.date()
    initialdate = initialdate.date()
    today=datetime.now().date()
    
    q = query(valuation).filter(valuation.code == code)
    date = pd.date_range(startdata,today)
    df = get_fundamentals(q,initialdate)
    
    for i in date:
        tmp = get_fundamentals(q,i)
        df = pd.concat([df,tmp])
    
    if os.path.exists(filename):
        df.to_csv(filepath,mode='a',header=None)
    else:
        df.to_csv(filepath)

# %%
data_dir = "C:\\quanttime\\data\\security_raw\\"

filename = data_dir + "000166.XSHE" + ".csv"
print (filename)
security = pd.read_csv(filename)
print (se)

# %%
from datetime import datetime,timedelta
startdate=datetime.strptime(security['day'].iloc[-1],"%Y-%m-%d") + timedelta(days=1)

print (startdate.date().strftime("%Y-%m-%d"))

# %%
startdate=datetime.strptime("2005/6/24","%Y/%m/%d") + timedelta(days=1)

print (startdate.date().strftime("%Y-%m-%d"))

# %%
q = query(finance.STK_AH_PRICE_COMP).filter(finance.STK_AH_PRICE_COMP.a_code=="600030.XSHG",finance.STK_AH_PRICE_COMP.day>='2006-01-01').order_by(finance.STK_AH_PRICE_COMP.day)
df = finance.run_query(q)
df = df[['day','name','a_price','h_price','h_a_comp']]
print(df)

# %%
from jaqs.data import DataApi

# %%
api = DataApi(addr="tcp://data.quantos.org:8910")
token = "eyJhbGciOiJIUzI1NiJ9.eyJjcmVhdGVfdGltZSI6IjE1MTI4Nzg4NDI2OTkiLCJpc3MiOiJhdXRoMCIsImlkIjoiMTM4MTE4NjY3NjMifQ.FsAb_NOHNcfnTYx8KQPIgSEPcfxS9C_gxiMYuDFI5SA"
api.login("13811866763",token)
df,msg = api.daily(symbol="600030.SH",start_date='2016-01-01',end_date='2018-06-30',field="",adjust_mode="post")

# %%
msg

# %%
from opendatatools import fx

# %%
df,msg = fx.get_hist_cny_cpr(start_date='2016-01-01',end_date='2018-06-30')

# %%
df

# %%
q1 = query(security_indicator).filter(security_indicator.code == '600837.XSHG')
df = get_fundamentals(q1, statDate="2017q1")
if df.empty:
    print ("Empty DataFrame")
print(df)

# %%
q2 = query(indicator).filter(indicator.code == "600837.XSHG")
df = get_fundamentals(q2,statDate="2017")
print(df)

# %%
allStocks = get_all_securities(types=[],date=None)
allStocks.to_csv("C:\\quanttime\\data\\basic_info\\all_security_info.csv")

# %%
stock_info = pd.read_csv("C:\\quanttime\\data\\basic_info\\all_stock_info.csv",encoding='gbk')
print (stock_info.head(5))

# %%
stock_info.iloc[0,0]

# %%
stock_info = pd.read_csv("C:\\quanttime\\data\\basic_info\\all_stock_info.csv", index_col="code", encoding="gbk")
print(stock_info.head(5))
code = "601318.XSHG"
name = stock_info.loc[code,["display_name"]]
print("=========")
print (name['display_name'])

# %%
create_dir_name =  code + name['display_name']
print (create_dir_name)

# %%
if not os.path.exists(create_dir_name):
    os.mkdir(create_dir_name)
else:
    print("the dir is existed!!!")

# %%
stock_info = pd.read_csv("C:\\quanttime\\data\\basic_info\\all_stock_info.csv",encoding='gbk')
print (stock_info.head(5))

# %%
print(stock_info.iloc[0,3])

# %%
table_name = ['valuation', 'balance', 'cash_flow', 'income', 'indicator']
rootpath = "C:\\quanttime\\data\\finance\\valuation\\"
end_time = datetime.today().date()
start_time = datetime.strptime(stock_info.iloc[0,3], "%Y/%m/%d")+ timedelta(days=180)
compare_time = datetime.strptime("2006-01-01","%Y-%m-%d")
if start_time < compare_time:
    start_time = compare_time
q = query(valuation).filter(valuation.code == stock_info.iloc[0,0])
if end_time > start_time.date():
    dates = pd.date_range(start_time, end_time)
    #print(dates)
    df_valuation = get_fundamentals(q,"2006-01-01")
    filepath = rootpath + str(stock_info.iloc[0,0]) + ".csv"
    for date in dates:
        tmp = get_fundamentals(q,date)
        df_valuation = pd.concat([df_valuation,tmp])
    df_valuation.to_csv(filepath)
    print("successful")

# %%
dt1=datetime.strptime("2018-07-02","%Y-%m-%d")+timedelta(days=40)
dt2=datetime.today().date()
print(dt1)
print(dt2)
if dt1.date()>dt2:
    print ("dt1<dt2")
else:
    print ("dt1>=dt2")

# %%
start_time = datetime.strptime(stock_info.iloc[0,3], "%Y/%m/%d")+ timedelta(days=180)
print(type(start_time))

# %%
q = query(valuation).filter(valuation.code == "601318.XSHG")
df = get_fundamentals(q,"2006-01-04")
df2=get_fundamentals(q,"2016-01-04")
df=pd.concat([df,df2])
print(df)

# %%
table_name = ['valuation', 'balance', 'cash_flow', 'income', 'indicator']
rootpath = "C:\\quanttime\\data\\finance\\valuation\\"
end_time = datetime.today().date()
start_time = datetime.strptime(stock_info.iloc[0,3], "%Y/%m/%d")+ timedelta(days=180)
compare_time = datetime.strptime("2006-01-01","%Y-%m-%d")
if start_time < compare_time:
    start_time = compare_time

    
for i in range(1,len(stock_info)):
    q = query(valuation).filter(valuation.code == stock_info.iloc[i,0])
    if end_time > start_time.date():
        dates = pd.date_range(start_time, end_time)
        #print(dates)
        df_valuation = get_fundamentals(q,"2006-01-01")
        filepath = rootpath + str(stock_info.iloc[i,0]) + ".csv"
        for date in dates:
            tmp = get_fundamentals(q,date)
            df_valuation = pd.concat([df_valuation,tmp])
        df_valuation.to_csv(filepath)
        print("successful")

# %%
for i in range(0,len(stock_info)):
    print (i)

# %%
table_name = ['valuation', 'balance', 'cash_flow', 'income', 'indicator']
#update数据的文件夹路径
valuation_file_path = "C:\\quanttime\\data\\finance\\valuation\\"
balance_file_path = "C:\\quanttime\\data\\finance\\balance\\"
cash_flow_file_path = "C:\\quanttime\\data\\finance\\cash_flow\\"
income_file_path = "C:\\quanttime\\data\\finance\\income\\"
indicator_file_path = "C:\\quanttime\\data\\finance\\indicator\\"

#获取所有stock信息
stock_info = pd.read_csv("C:\\quanttime\\data\\basic_info\\all_stock_info.csv",encoding='gbk')

statdate=["2006q1","2006q2","2006q3","2006q4","2006", \
          "2007q1","2007q2","2007q3","2007q4","2007", \
          "2008q1","2008q2","2008q3","2008q4","2008", \
          "2009q1","2009q2","2009q3","2009q4","2009", \
          "2010q1","2010q2","2010q3","2010q4","2010", \
          "2011q1","2011q2","2011q3","2011q4","2011", \
          "2012q1","2012q2","2012q3","2012q4","2012", \
          "2013q1","2013q2","2013q3","2013q4","2013", \
          "2014q1","2014q2","2014q3","2014q4","2014", \
          "2015q1","2015q2","2015q3","2015q4","2015", \
          "2016q1","2016q2","2016q3","2016q4","2016", \
          "2017q1","2017q2","2017q3","2017q4","2017", \
          "2018q1","2018q2","2018q3","2018q4","2018"]

#获取balance表
for i in range(0,len(stock_info)):
    filepath = balance_file_path + str(stock_info.iloc[i,0]) + ".csv"
    q = query(balance).filter(balance.code == stock_info.iloc[i,0])
    df_balance = get_fundamentals(q,statDate = "2006q1")
    for date in statdate:
        tmp = get_fundamentals(q,statDate=date)
        df_balance = pd.concat([df_balance,tmp])
    df_balance.to_csv(filepath)
    print("get balance code:%r successful"%(stock_info.iloc[i,0]))
    
#获取cash_flow表
for i in range(0,len(stock_info)):
    filepath = cash_flow_file_path + str(stock_info.iloc[i,0]) + ".csv"
    q = query(cash_flow).filter(cash_flow.code==stock_info.iloc[i,0])
    df_cash = get_fundamentals(q, statDate = "2006q1")
    for date in statdate:
        tmp = get_fundamentals(q,statDate=date)
        df_cash = pd.concat([df_cash,tmp])
    df_cash.to_csv(filepath)
    print("get cash flow code:%r successful"%(stock_info.iloc[i,0]))
    
#获取income表
for i in range(0,len(stock_info)):
    filepath = income_file_path + str(stock_info.iloc[i,0]) + ".csv"
    q = query(income).filter(income.code==stock_info.iloc[i,0])
    df_income = get_fundamentals(q, statDate = "2006q1")
    for date in statdate:
        tmp = get_fundamentals(q,statDate=date)
        df_income = pd.concat([df_income,tmp])
    df_income.to_csv(filepath)
    print("get income code:%r successful"%(stock_info.iloc[i,0]))
    
#获取indicator表
for i in range(0,len(stock_info)):
    filepath = indicator_file_path + str(stock_info.iloc[i,0]) + ".csv"
    q = query(indicator).filter(indicator.code==stock_info.iloc[i,0])
    df_indicator = get_fundamentals(q, statDate = "2006q1")
    for date in statdate:
        tmp = get_fundamentals(q,statDate=date)
        df_indicator = pd.concat([df_indicator,tmp])
    df_indicator.to_csv(filepath)
    print("get indicator code:%r successful"%(stock_info.iloc[i,0]))

# %%
q = query(valuation).filter(valuation.code == "601318.XSHG")
df_601318 = get_fundamentals_continuously(q, end_date='2018-07-30', count=10000)
df_601318.minor_xs('601318.XSHG').to_csv("C:\\quanttime\\data\\finance\\valuation\\601318.csv")

# %%
df_601318.minor_xs('601318.XSHG').to_csv("C:\\quanttime\\data\\finance\\valuation\\601318.csv")

# %%
valuation_file_path = "C:\\quanttime\\data\\finance\\valuation\\"
for i in range(3063,len(stock_info)):
    filepath = valuation_file_path + str(stock_info.iloc[i,0]) + ".csv"
    if(str(stock_info.iloc[i,4]) != "2200/1/1"):
        print("2200")
        continue
    q = query(valuation).filter(valuation.code == stock_info.iloc[i,0])
    try:
        df_valuation = get_fundamentals_continuously(q,end_date="2018-07-30",count=2000)
    except KeyError:
        print("code:%r tuishi"%(stock_info.iloc[i,0]))
        continue
    df_valuation.minor_xs(str(stock_info.iloc[i,0])).to_csv(filepath)
    print("get valuation code:%r successful"%(stock_info.iloc[i,0]))

# %%
endtime = datetime.today().date().strftime("%Y-%m-%d")
print(endtime)

# %%
#获取所有stock信息
stock_info = pd.read_csv("C:\\quanttime\\data\\basic_info\\all_stock_info.csv",encoding='gbk')
#1、更新 valuation表
end_time = datetime.today().date().strftime("%Y-%m-%d")
valuation_file_path = "C:\\quanttime\\data\\finance\\valuation\\"
for i in range(0,1):
    file_path = valuation_file_path + str(stock_info.iloc[i, 0]) + ".csv"
    q = query(valuation).filter(valuation.code == stock_info.iloc[i, 0])
    df_valuation = get_fundamentals_continuously(q,end_date=end_time,count=5)
    if os.path.exists(file_path):
        df_valuation.minor_xs(str(stock_info.iloc[i,0])).to_csv(file_path,mode='a',header=None)
    else:
        df_valuation.minor_xs(str(stock_info.iloc[i,0])).to_csv(file_path)

# %%
gold_hisdata = get_price('IC1904.CCFX', start_date="2019-01-01", end_date="2019-06-15")
gold_hisdata
# Out:
#               open   close    high     low  volume        money
# 2019-01-02     NaN     NaN     NaN     NaN     NaN          NaN
# 2019-01-03     NaN     NaN     NaN     NaN     NaN          NaN
# 2019-01-04     NaN     NaN     NaN     NaN     NaN          NaN
# 2019-01-07     NaN     NaN     NaN     NaN     NaN          NaN
# 2019-01-08     NaN     NaN     NaN     NaN     NaN          NaN
# 2019-01-09     NaN     NaN     NaN     NaN     NaN          NaN
# 2019-01-10     NaN     NaN     NaN     NaN     NaN          NaN
# 2019-01-11     NaN     NaN     NaN     NaN     NaN          NaN
# 2019-01-14     NaN     NaN     NaN     NaN     NaN          NaN
# 2019-01-15     NaN     NaN     NaN     NaN     NaN          NaN
# 2019-01-16     NaN     NaN     NaN     NaN     NaN          NaN
# 2019-01-17     NaN     NaN     NaN     NaN     NaN          NaN
# 2019-01-18     NaN     NaN     NaN     NaN     NaN          NaN
# 2019-01-21     NaN     NaN     NaN     NaN     NaN          NaN
# ...

# %%
gold_hisdata.iloc[50:80]
# Out:
#               open   close    high     low   volume         money
# 2019-03-20  5482.0  5470.0  5503.4  5352.2  60872.0  6.621759e+10
# 2019-03-21  5485.0  5541.4  5628.0  5485.0  68987.0  7.679528e+10
# 2019-03-22  5560.4  5611.2  5614.0  5470.0  61671.0  6.846269e+10
# 2019-03-25  5523.0  5518.6  5597.0  5506.6  60231.0  6.691081e+10
# 2019-03-26  5555.0  5358.0  5559.4  5345.0  61628.0  6.704541e+10
# 2019-03-27  5389.0  5391.6  5415.0  5313.2  57409.0  6.167107e+10
# 2019-03-28  5372.6  5318.6  5447.6  5311.2  59915.0  6.448670e+10
# 2019-03-29  5333.2  5534.4  5555.2  5322.4  65790.0  7.158942e+10
# 2019-04-01  5574.8  5766.0  5767.4  5574.8  61104.0  6.978878e+10
# 2019-04-02  5795.2  5746.6  5825.6  5722.6  52935.0  6.124433e+10
# 2019-04-03  5716.0  5828.6  5852.2  5712.6  52822.0  6.107199e+10
# 2019-04-04  5858.0  5882.6  5898.0  5792.4  55547.0  6.499134e+10
# 2019-04-08  5929.0  5800.8  5935.0  5737.4  59401.0  6.930882e+10
# ...

# %%
get_extras("futures_sett_price",["IC1904.CCFX"],start_date="2019-04-17", end_date="2019-04-22")
# Out:
#             IC1904.CCFX
# 2019-04-17       5783.6
# 2019-04-18       5778.4
# 2019-04-19       5779.8
# 2019-04-22          NaN

# %%
gold_hisdata.index.name = "date"

# %%
gold_hisdata.head(5)

# %%
gold_hisdata.to_csv("C:\\quanttime\\data\\gold\\sh_future\\gold.csv")

# %%
gold = pd.read_csv("C:\\quanttime\\data\\gold\\sh_future\\gold.csv",index_col=["date"])
gold.index

# %%
d1 = datetime.strptime(gold.index[-1],'%Y-%m-%d')
d2 = datetime.strptime(gold.index[0],'%Y-%m-%d')

delta = d1 - d2
delta2 = timedelta(days=1)
if delta.days > 0:
    d1 = d1+delta2
    endtime = d1.strftime('%Y-%m-%d')
else:
    d2 = d2 + delta2
    endtime = d2.trftime('%Y-%m-%d')

endtime

# %%
get_all_securities(types=['index'], date=None)

# %%
index_1 = pd.DataFrame(columns=["display_name","date","weight"],index=['code'])
index_1

# %%
index_2 = get_index_weights("399975.XSHE","2018-02-27")
index_2

# %%
index399975 = pd.concat([index_1,index_2]).dropna()
#index399975.to_csv("C:\\quanttime\\data\\index\\weights\\399975.XSHE.csv",encoding="gbk")
index399975.head(5)

# %%
index399975 = pd.read_csv("C:\\quanttime\\data\\index\\weights\\399975.XSHE.csv",encoding="gbk",index_col=["date","code"])
index399975

# %%
index399975.index.levels[0]

# %%
for i in index399975.index.levels[0]:
    print (i)

# %%
dt1 = []
for i in index399975.index.levels[0]:
    if '/' in i:
        dt1.append(datetime.strptime(i,"%Y/%m/%d"))
    if '-' in i:
        dt1.append(datetime.strptime(i,"%Y-%m-%d"))
dt1

# %%
index_all_info_dir = "C:\\quanttime\\data\\basic_info\\index_all_info.csv"
index_all_info = pd.read_csv(index_all_info_dir, index_col=["code"], encoding="gbk")
data_dir = "C:\\quanttime\\data\\finance\\valuation\\"
index_dir = "C:\\quanttime\\data\\index\\index_valuation\\"
index_all_info.index

# %%
test_list = ['399975.XSHE']
for index_code in test_list:
    stocks = get_index_stocks(index_code, "2018-12-10")
    print(stocks)

# %%
dates = pd.date_range("2006-01-01","2018-12-18")
df_valuation_all = pd.DataFrame(columns=["pb_ratio", "pe_ratio"], index=dates)
df_valuation_all.index.name = "day"
df_valuation_all
file_path = data_dir + '600030.XSHG' + '.csv'
df_valuation = pd.read_csv(file_path,index_col=['day'], usecols=["day", "pe_ratio", "pb_ratio"])
df_valuation

# %%
stocks = ['600030.XSHG','600109.XSHG']
for code in stocks:
    file_path = data_dir + str(code) + '.csv'
    df_valuation = pd.read_csv(file_path,index_col=['day'], usecols=["day", "pe_ratio", "pb_ratio"])
    df_valuation_all = pd.merge(df_valuation_all, df_valuation,left_index=True,right_index=True,suffixes=('_%r'%code,'_%r'%code))
df_valuation_all.to_csv(index_dir + str(code) +'_raw.csv')

# %%
q = query(valuation).filter(valuation.code == "601318.XSHG")
df_valuation = get_fundamentals(q, "2001-10-01")
df_valuation

# %%
df_valuation1 = get_fundamentals(q, "2018-10-01")
tmpdf = pd.concat([df_valuation,df_valuation1])
tmpdf

# %%
valuation_file_path = "C:\\quanttime\\data\\finance\\valuation\\"
stock_codes = ["000002.XSHE"]
for code in stock_codes:
    update_file = valuation_file_path + code + ".csv"
    if (os.path.exists(update_file)):
        valuation_data = pd.read_csv(update_file)
        print("去重前，数据行数：%r"%len(valuation_data.index))
valuation_data.head(5)

# %%
valuation_data = valuation_data.drop_duplicates('day')
#valuation_data = valuation_data[~valuation_data.reset_index().duplicated().values]
print("去重后，数据行数：%r"%len(valuation_data.index))
valuation_data.to_csv(update_file,index=False)

# %%
d1 = pd.read_csv("C:\\quanttime\\data\\basic_info\\all_trade_day.csv",index_col=["trade_date"])
d1.loc["2005-01-04"][0]

# %%
def get_close_trade_date(strDate, direct):
    trade_date = pd.read_csv("C:\\quanttime\\data\\basic_info\\all_trade_day.csv",index_col=["trade_date"])
    if direct == -1:
        dates = pd.date_range(end=strDate,periods=10)
        dates = list(reversed(dates.tolist()))
        for tmpDate in dates:
            try:
                return trade_date.index[trade_date.index.tolist().index(tmpDate.date().strftime("%Y-%m-%d"))]
            except ValueError:
                continue
    elif direct == 1:
        dates = pd.date_range(start=strDate,periods=10)
        for tmpDate in dates.tolist():
            try:
                return trade_date.index[trade_date.index.tolist().index(tmpDate.date().strftime("%Y-%m-%d"))]
            except ValueError:
                continue
    else:
        return strDate
    return strDate

get_close_trade_date("2018-10-05",1)

# %%
df = pd.date_range(end="2018-10-01",periods=10)
df = list(reversed(df.tolist()))
df

# %%
df.loc['2018-12-28',['close']].close

# %%
current_date = (datetime.today().date()-timedelta(1)).strftime("%Y-%m-%d")
current_df = get_price("399975.XSHE", start_date=current_date, end_date=current_date, frequency='daily',
                                   fields=None)
print(current_date)
print(current_df)

# %%
def get_trade_list(startDate, endDate):
    trade_date = pd.read_csv("C:\\quanttime\\data\\basic_info\\all_trade_day.csv",index_col=["trade_date"])
    
    start = trade_date.loc[startDate][0]
    end = trade_date.loc[endDate][0]
    trade_days = trade_date.iloc[start:end,0]
    return trade_days.index.tolist()
    
get_trade_list("2018-10-08","2018-10-16")

# %%
isinstance("2018-10-01",str)

# %%
# %load c://quanttime//src/index//get_index_trade_event.py
__author__ = 'Administrator'
import sys

import tushare as ts
from datetime import datetime, timedelta
import pandas as pd
import logging
from jqdatasdk import *
from prettytable import PrettyTable


def indexTrade():
    '''
    功能：通过比较10,20日等的收盘价，判断是否买入或者卖出
    当前比较基准有：
    1、当前价格与20日前收盘价进行比较，如果高则买入，如果低则卖出
    2、当前价格与20日前收盘价进行比较，如果高则买入，当前价格与10日前收盘价比较，如果低则卖出
    3、当前价格与76日前收盘价进行比较，如果高则买入，当前价格与33日前收盘价比较，如果低则卖出
    :return:
    '''
    auth('13811866763', "sam155")  # jqdata 授权
    # 所用文件目录如下：
    index_basic_info_dir = "C:\\quanttime\\data\\basic_info\\index_trade.csv"
    index_k_dir = "C:\\quanttime\\data\\index\\jq\\"
    #index 基本信息等
    df_index_info = pd.read_csv(index_basic_info_dir, index_col=["code"], encoding="gbk")

    all_trade_day = pd.read_csv("C:\\quanttime\\data\\basic_info\\all_trade_day.csv", index_col=["trade_date"])

    result = []
    for index1 in df_index_info.index:
        row_record = []
        index_file = index_k_dir + str(index1) + ".csv"
        index_name = df_index_info.loc[index1, ["display_name"]].display_name
        current_date = datetime.today().date().strftime("%Y-%m-%d")
        #current_date = "2018-12-28" #for test
        # 获取当时的价格
        current_df = get_price(index1, start_date=current_date, end_date=current_date, frequency='daily', fields=None)
        # print(index_name)
        row_record.append(index_name)
        try:
            index_k_data = pd.read_csv(index_file, index_col=["date"])
            row_record.append(current_date)
            # 1、与前20天的情况比较，当前持有则低于前20日收盘价则卖出，当前空仓则高于前20日收盘价则买入
            back_trace = 20
            if all_trade_day.index.tolist().index(current_date) - back_trace >= 0:
                pre_date = all_trade_day.index[all_trade_day.index.tolist().index(current_date) - back_trace]
                pre_value = index_k_data.loc[pre_date, ['close']].close
                current = current_df.loc[current_date,['close']].close #当前的close价格
                if float(pre_value) > float(current):
                    # compare = u'当前close低于20日前close'
                    compare = 'sell c:%r vs p:%r '%(current,pre_value)
                    row_record.append(compare)
                    # print("%r-%r 当前价格低于20日前"%(index1,index_name))
                else:
                    # compare = u'当前close高于（或等于）20日前close'
                    compare = 'buy c:%r vs p:%r '%(current,pre_value)
                    row_record.append(compare)
                    # print("%r-%r 当前价格高于20日前"%(index1,index_name))
                # 2、前20日收盘价，前10日收盘价情况比较，当前持有则低于前10日收盘价则卖出，当前空仓则高于前20日收盘价则买入
                back_trace = 10
                pre_date = all_trade_day.index[all_trade_day.index.tolist().index(current_date) - back_trace]
                pre_value = index_k_data.loc[pre_date, ['close']].close
                if float(current) >= float(pre_value):
                    # compare = u'当前close高于等于20日前close'
                    compare = 'buy c:%r vs p:%r '%(current,pre_value)
                    row_record.append(compare)
                elif float(current) < float(index_k_data.loc[pre_date, ['close']].close):
                    # compare = u'当前close低于10日前close'
                    compare = 'sell c:%r vs p:%r '%(current,pre_value)
                    row_record.append(compare)
                else:
                    # compare = u'当前close介于20日前close与10日前close之间'
                    compare = 'hold c:%r vs p:%r '%(current,pre_value)
                    row_record.append(compare)
            # 3、买入与前76日收盘价比较，卖出与33日收盘价比较，即当前close高于前76日close则买入或继续持有，当前close低于前33日close则卖出
            back_trace = 76
            if all_trade_day.index.tolist().index(current_date) - back_trace >= 0:
                pre_date = all_trade_day.index[all_trade_day.index.tolist().index(current_date) - back_trace]
                pre_date_33 = all_trade_day.index[all_trade_day.index.tolist().index(current_date) - 33]
                pre_value = index_k_data.loc[pre_date, ['close']].close
                #current = index_k_data.loc[current_date, ['close']].close
                # print(pre_value)
                # print(current)
                if float(current) >= float(pre_value):
                    # compare = u'当前close高于等于76日前close'
                    compare = 'buy c:%r vs p:%r '%(current,pre_value)
                    row_record.append(compare)
                elif float(current) < float(index_k_data.loc[pre_date_33, ['close']].close):
                    # compare = u'当前close低于33日前close'
                    compare = 'sell c:%r vs p:%r '%(current,pre_value)
                    row_record.append(compare)
                else:
                    # compare = u'当前close介于76日前close与33日前close之间'
                    compare = 'hold c:%r vs p:%r '%(current,pre_value)
                    row_record.append(compare)
        except:
            print("%r process error" % index1)
            continue
        # print(row_record)
        result.append(row_record)
    df_columns = ['index_name', 'date', '20buy VS 20sell', u'20buy VS 10sell', u'76buy vs 33sell']
    df = pd.DataFrame(data=result, index=df_index_info.index, columns=df_columns)
    buy_sell_table = PrettyTable(df_columns)
    buy_sell_table.align['index_name'] = "l"
    buy_sell_table.padding_width = 1
    for row_value in result:
        buy_sell_table.add_row(row_value)
    #print(df.head(5))
    print(buy_sell_table)

#============================================================================================
def index_rotation():
    '''
    功能：指数轮动，即常见的如二八轮动，二八轮动plus
    1、二八轮动。即采用沪深300与中证500指数作为轮动标的，当前价格与20日前close价格对比，哪个涨幅大持有哪个，都下跌则不持有
    2、二八轮动plus，则在上诉基础上加入一个均值判断，即在判断哪个涨幅大的基础上，在与19,20,21日三天的均值进行比较，大于/小于均值才转换
    :return:
    '''

    #比较的指数对,当前沪深300VS中证500，沪深300VS创业板50
    compare_indexs_list = [["000300.XSHG", "399905.XSHE"],["000300.XSHG", "399673.XSHE"]]
    auth('13811866763', "sam155")  # jqdata 授权
    # 所用文件目录如下：
    index_basic_info_dir = "C:\\quanttime\\data\\basic_info\\index_trade.csv"
    index_k_dir = "C:\\quanttime\\data\\index\\jq\\"
    # index 基本信息等
    df_index_info = pd.read_csv(index_basic_info_dir, index_col=["code"], encoding="gbk")

    all_trade_day = pd.read_csv("C:\\quanttime\\data\\basic_info\\all_trade_day.csv", index_col=["trade_date"])


    row_record = []
    for index_pair in compare_indexs_list:
        if len(index_pair) != 2:
            continue

        #===============
        pre_value_list = [] #存放tmp_pre_list，即两个指数的21,20,19的close值，其中分别是两个list，放在pre_value_list中
        current_list = []
        index_name_list = []
        current_date = datetime.today().date().strftime("%Y-%m-%d")
        #current_date = "2018-12-28" #for test
        for index in index_pair:
            tmp_pre_list = []  # 用于暂时存储21,20,19的close值
            index_file = index_k_dir + str(index) + ".csv"
            index_name = df_index_info.loc[index, ["display_name"]].display_name
            index_name_list.append(index_name)
            # 获取当时的价格
            current_df = get_price(index, start_date=current_date, end_date=current_date, frequency='daily',
                                   fields=None)
            if current_df.empty:
                print("index: %r  get price empty check date!!!")
                continue
            current_list.append(current_df.loc[current_date, ['close']].close)   # 当前的close价格
            index_k_data = pd.read_csv(index_file, index_col=["date"])

            # 21,20,19
            for back_trace in range(21, 18, -1):
                if all_trade_day.index.tolist().index(current_date) - back_trace >= 0:
                    pre_date = all_trade_day.index[all_trade_day.index.tolist().index(current_date) - back_trace]
                    pre_value = index_k_data.loc[pre_date, ['close']].close
                    tmp_pre_list.append(float(pre_value))

            pre_value_list.append(tmp_pre_list)

        print(pre_value_list)
        #1、二八轮动判断
        index0 = float(current_list[0]) > float(pre_value_list[0][1])
        print("index:%r(%r),current close:%r,before 20day close:%r" % \
              (index_pair[0],index_name_list[0],current_list[0],pre_value_list[0][1]))
        index1 = float(current_list[1]) > float(pre_value_list[1][1])
        print("index:%r(%r),current close:%r,before 20day close:%r" % \
              (index_pair[1], index_name_list[1], current_list[1], pre_value_list[1][1]))

        if index0 and index1: #两个指数都比各自的20日前的close价高，两个指数都进入买入门槛
            index0_diff = (float(current_list[0]) - float(pre_value_list[0][1]))/ float(pre_value_list[0][1])
            index1_diff = (float(current_list[1]) - float(pre_value_list[1][1]))/ float(pre_value_list[1][1])
            if index0_diff > index1_diff:
                result = "buy %r(%r)"%(index_pair[0],index_name_list[0])
            elif index0_diff < index1_diff:
                result = "buy %r(%r)"%(index_pair[1],index_name_list[1])
            else:
                result = "%r(%r),%r(%r) amount of increase equality"% \
                         (index_pair[0],index_name_list[0],index_pair[1],index_name_list[1])
        elif index0 and (not index1):# index0>0.index1<0,取index0
            result = "buy %r(%r)" % (index_pair[0], index_name_list[0])
        elif (not index0) and index1:
            result = "buy %r(%r)" % (index_pair[1], index_name_list[1])
        else:
            result = "sell %r(%r),%r(%r) all"%(index_pair[0],index_name_list[0],index_pair[1],index_name_list[1])

        tmp_row_result = ["28stander", current_date, result]
        row_record.append(tmp_row_result)

        #2、二八轮动plus
        #19,20,21,三天收盘价的均值
        pre_index0_mean = sum(pre_value_list[0]) / len(pre_value_list[0])
        pre_index1_mean = sum(pre_value_list[1]) / len(pre_value_list[1])
        index0 = float(current_list[0]) > float(pre_index0_mean)
        print("index:%r(%r),current close:%r,before 20day !!mean!! close:%r" % \
              (index_pair[0], index_name_list[0], current_list[0], pre_index0_mean))
        index1 = float(current_list[1]) > float(pre_index1_mean)
        print("index:%r(%r),current close:%r,before 20day !!mean!! close:%r" % \
              (index_pair[1], index_name_list[1], current_list[1], pre_index1_mean))

        if index0 and index1: #两个指数都比各自的20日前平均的close价高，两个指数都进入买入门槛
            index0_diff = (float(current_list[0]) - pre_index0_mean)/ pre_index0_mean
            index1_diff = (float(current_list[1]) - pre_index1_mean)/ pre_index1_mean
            if index0_diff > index1_diff:
                result = "buy %r(%r)"%(index_pair[0],index_name_list[0])
            elif index0_diff < index1_diff:
                result = "buy %r(%r)"%(index_pair[1],index_name_list[1])
            else:
                result = "%r(%r),%r(%r) amount of increase equality"% \
                         (index_pair[0],index_name_list[0],index_pair[1],index_name_list[1])
        elif index0 and (not index1):# index0>0.index1<0,取index0
            result = "buy %r(%r)" % (index_pair[0], index_name_list[0])
        elif (not index0) and index1:
            result = "buy %r(%r)" % (index_pair[1], index_name_list[1])
        else:
            result = "sell %r(%r),%r(%r) all"%(index_pair[0],index_name_list[0],index_pair[1],index_name_list[1])

        tmp_row_result = ["28 plus", current_date, result]
        row_record.append(tmp_row_result)

    table_columns = ['strategy_name', 'date', "result"]
    buy_sell_table = PrettyTable(table_columns)
    buy_sell_table.align['strategy_name'] = "l"
    buy_sell_table.padding_width = 1
    for row_value in row_record:
        buy_sell_table.add_row(row_value)

    print(buy_sell_table)







if __name__ == "__main__":
    indexTrade()
    index_rotation()

# %%
get_index_stocks("000004.XSHG", "2018-12-28")

# %%
index_all_info_dir = "C:\\quanttime\\data\\basic_info\\index_all_valuation_info.csv"   
index_all_info = pd.read_csv(index_all_info_dir, index_col=["code"], encoding="gbk")
for code in index_all_info.index:
    print("%r len: %r"%(code,len(get_index_stocks(code, "2018-12-28"))))

# %%
def get_close_trade_date(strDate, direct):
    '''
        功能：获取节假日最近的一个交易日，比如2018-10-1日，的前一个交易日是9-28日
        这里是生成了一个已strDate为end的，往前推10个日期的时间序列
        :param strDate：str类型日期，如"2018-10-01"
               1:日期之后的交易时间，如2018-10-01日后的交易日期
               -1：日期之前的交易时间，如2018-10-01日前的交易日期
        :return:str 类型，如果没有找到则返回strDate的值
    '''
    trade_date = pd.read_csv("C:\\quanttime\\data\\basic_info\\all_trade_day.csv", index_col=["trade_date"])
    if direct == -1:
        dates = pd.date_range(end=strDate, periods=10)
        dates = list(reversed(dates.tolist()))
        for tmpDate in dates:
            try:
                return trade_date.index[trade_date.index.tolist().index(tmpDate.date().strftime("%Y-%m-%d"))]
            except ValueError:
                continue
    elif direct == 1:
        dates = pd.date_range(start=strDate, periods=10)
        for tmpDate in dates.tolist():
            try:
                return trade_date.index[trade_date.index.tolist().index(tmpDate.date().strftime("%Y-%m-%d"))]
            except ValueError:
                continue
    else:
        return strDate
    return strDate

def get_trade_list(startDate, endDate):
    '''
    功能：获取startDate, endDate交易日时间段，该时间查表于all_trade_day.csv
    :param startDate: str，该值需要在all_trade_day.csv内
    :param endDate: str 该值需要在all_trade_day.csv
    :return: list
    '''
    trade_date = pd.read_csv("C:\\quanttime\\data\\basic_info\\all_trade_day.csv",index_col=["trade_date"])
    try:
        start = trade_date.loc[startDate][0]
        end = trade_date.loc[endDate][0]
    except:
        return []
    trade_days = trade_date.iloc[start:end, 0]
    return trade_days.index.tolist()

index_all_info_dir = "C:\\quanttime\\data\\basic_info\\index_all_valuation_info.csv"
index_all_info = pd.read_csv(index_all_info_dir, index_col=["code"], encoding="gbk")
data_dir = "C:\\quanttime\\data\\finance\\valuation\\"
#df_valuation_all = pd.DataFrame(columns=["pb_ratio", "pe_ratio"], index=['day'])
for code in index_all_info.index:
    start_date = index_all_info.loc[code, ["start_date"]].start_date
    start_date = get_close_trade_date(start_date, 1)
    end_date = "2018-12-28"
    trade_days = get_trade_list(start_date, end_date)
    if "-" in start_date:
        start_month = datetime.strptime(start_date,"%Y-%m-%d").month
    if "/" in start_date:
        start_month = datetime.strptime(start_date,"%Y/%m/%d").month
    stocks = []
    trade_month_list = []
    tmp_month_list = []
    for day in trade_days:
        month = datetime.strptime(day,"%Y-%m-%d").month
        if start_month == month:
            #stocks = get_index_stocks(code, day)  # 指定日期指数各成分股，返回一个list
            tmp_month_list.append(day)
        else:
            trade_month_list.append(tmp_month_list)
            tmp_month_list.clear()
            tmp_month_list.append(day)
            start_month = month
        print(tmp_month_list)
    #print(trade_month_list)

# %%
df_1 = pd.read_csv("C:\\quanttime\\data\\finance\\valuation\\000000.XSHG.csv",index_col=['day'], \
                                       usecols=["day","pe_ratio","pb_ratio"])
df_2 = pd.read_csv("C:\\quanttime\\data\\finance\\valuation\\601318.XSHG.csv",index_col=['day'], \
                                       usecols=["day","pe_ratio","pb_ratio"])
suff1 = '_'
suff2 = '_%r'%(2)
df_3 = pd.merge(df_1,df_2,how="outer",left_index=True,right_index=True,suffixes=(suff1,suff2))
df_3[df_3>22] = 0
df_3

# %%
df_valuation = pd.read_csv("C:\\quanttime\\data\\finance\\valuation\\000000.XSHG.csv",index_col=['day'], \
                                       usecols=["day","pe_ratio","pb_ratio"])
            for stock in stocks:
                valuation_file = data_dir + str(stock) + '.csv'
                if os.path.exists(valuation_file):
                    df_tmp = pd.read_csv(stock_path,index_col=['day'], usecols=["day","pe_ratio","pb_ratio"])
                    df_tmp = df_tmp[~df_tmp.reset_index().duplicated().values]#去重
                    if !df.empty:
                        suff2 = '_%r'%(stock[0:7])
                        df_valuation = pd.merge(df_valuation,df_tmp,how="outer",left_index=True,right=True,suffixes=('_x',suff2))

# %%
get_index_stocks('399996.XSHE', date="2018-12-28")

# %%
trade_date = pd.read_csv("C:\\quanttime\\data\\basic_info\\all_trade_day.csv",index_col=["trade_date"])
start = trade_date.loc["2005/01/04"][0]
start

# %%
pd.date_range()

# %%
[1,2] == [1,2]

# %%
current_date = datetime.today().date().strftime("%Y-%m-%d")
au_price = get_price('AU9999.XSGE',start_date="2019-03-08 09:00:00", end_date="2019-03-10 15:00:00", frequency='1m', fields=None)
au_price

# %%
au_price.to_csv("c:\\quanttime\\data\\gold\\sh_future\\tmp1.csv")

# %%
date1 = get_all_trade_days()
date2 = pd.DataFrame(date1)
date2.to_csv("C:\\quanttime\\data\\basic_info\\all_trade_date_new.csv")

# %%
stock_basic_info_dir = "C:\\quanttime\\data\\basic_info\\all_stock_info.csv"
get_from_jq = get_all_securities(types=["stock"],date=None)
stock_info_basic = pd.read_csv(
            stock_basic_info_dir,
            index_col=["code"],
            encoding="gbk")

# %%
get_from_jq.index.name = "code"
get_from_jq.head(5)
# Out:
#             display_name  name start_date   end_date   type
# code
# 000001.XSHE         平安银行  PAYH 1991-04-03 2200-01-01  stock
# 000002.XSHE          万科A   WKA 1991-01-29 2200-01-01  stock
# 000004.XSHE         国农科技  GNKJ 1990-12-01 2200-01-01  stock
# 000005.XSHE         世纪星源  SJXY 1990-12-10 2200-01-01  stock
# 000006.XSHE         深振业A  SZYA 1992-04-27 2200-01-01  stock

# %%
get_from_jq.to_csv("C:\\quanttime\\data\\basic_info\\all_stock_info111111.csv",encoding="gbk")

# %%
import pymongo

# %%
mongo_client = pymongo.MongoClient('mongodb://localhost:27017/')
basic_info_db = mongo_client["basic_info_db"]
all_stock_info = basic_info_db["all_stock_info"]
ret = all_stock_info.drop()
# Out:
# None

# %%
import tushare as ts
token = "17e7755e254f02cc312b8b7e22ded9a308924147f8546fdfbe653ba1"
ts.set_token(token)
# ts 授权
pro = ts.pro_api()

# %%
tmp = pro.index_basic(market="CSI")
# Out:
#          ts_code            name market publisher category base_date  \
# 0     000171.CSI            新兴成指    CSI      中证公司     主题指数  20101231
# 1     000801.CSI            资源80    CSI      中证公司     主题指数  20041231
# 2     000803.CSI           300波动    CSI      中证公司     策略指数  20041231
# 3     000804.CSI           500波动    CSI      中证公司     策略指数  20041231
# 4     000809.CSI            细分农业    CSI      中证公司     主题指数  20041231
# 5     000810.CSI            细分能源    CSI      中证公司     主题指数  20041231
# 6     000811.CSI            细分有色    CSI      中证公司     主题指数  20041231
# 7     000812.CSI            细分机械    CSI      中证公司     主题指数  20041231
# 8     000813.CSI            细分化工    CSI      中证公司     主题指数  20041231
# 9     000815.CSI            细分食品    CSI      中证公司     主题指数  20041231
# 10    000818.CSI            细分金融    CSI      中证公司     主题指数  20041231
# 11    000822.CSI         中证500红利    CSI      中证公司     主题指数  20041231
# 12    000824.CSI          中证国企红利    CSI      中证公司     主题指数  20090630
# ...

# %%
set(tmp["ts_code"].values)
# Out:
# {'h20702.CSI',
#  '930755.CSI',
#  'h30377.CSI',
#  'h20386.CSI',
#  '930746.CSI',
#  '930920.CSI',
#  'h01073.CSI',
#  'h30354.CSI',
#  'h30408.CSI',
#  'h30461.CSI',
#  '930872.CSI',
#  'h11158.CSI',
#  'h20960.CSI',
#  'h30095.CSI',
#  'h20856.CSI',
#  'h20829.CSI',
#  '930834.CSI',
#  'h30003.CSI',
#  'h30086.CSI',
#  'h00922.CSI',
#  'h01001.CSI',
#  '931058.CSI',
#  'h00815.CSI',
#  'h30385.CSI',
#  '930742.CSI',
#  'h00827.CSI',
#  'h11024.CSI',
#  'h20185.CSI',
#  'h01087.CSI',
#  'n11002.CSI',
#  'h30073.CSI',
#  'n30831.CSI',
#  'h21085.CSI',
#  'h20730.CSI',
#  'n00905.CSI',
#  'h20931.CSI',
#  'h30205.CSI',
#  'h20391.CSI',
#  '930958.CSI',
#  'h20958.CSI',
#  'h11059.CSI',
#  'h30429.CSI',
#  '930870.CSI',
#  'h20667.CSI',
#  'h20784.CSI',
#  'h20962.CSI',
#  '930790.CSI',
#  'h30412.CSI',
#  'h01130.CSI',
#  'h00941.CSI',
#  'h11054.CSI',
#  'h30077.CSI',
#  '930876.CSI',
#  'h01124.CSI',
#  'h20429.CSI',
#  'h20828.CSI',
#  '931106.CSI',
#  '930885.CSI',
# ...

# %%
data = pd.read_csv("C:\\quanttime\\data\\index\\jq\\000001.XSHG.csv",index_col=["date"],parse_dates=["date"])
data.index[-1].date()
# Out:
# datetime.date(2019, 4, 22)

# %%
df_stocks_info = get_all_securities(types=['stock'])
# 提取还在上市的股票
df_stocks_info = df_stocks_info[df_stocks_info["end_date"]=="2200-01-01"]

df_stocks_info
# Out:
#             display_name   name start_date   end_date   type
# 000001.XSHE         平安银行   PAYH 1991-04-03 2200-01-01  stock
# 000002.XSHE          万科A    WKA 1991-01-29 2200-01-01  stock
# 000004.XSHE         国农科技   GNKJ 1990-12-01 2200-01-01  stock
# 000005.XSHE         世纪星源   SJXY 1990-12-10 2200-01-01  stock
# 000006.XSHE         深振业A   SZYA 1992-04-27 2200-01-01  stock
# 000007.XSHE          全新好    QXH 1992-04-13 2200-01-01  stock
# 000008.XSHE         神州高铁   SZGT 1992-05-07 2200-01-01  stock
# 000009.XSHE         中国宝安   ZGBA 1991-06-25 2200-01-01  stock
# 000010.XSHE        *ST美丽  *STML 1995-10-27 2200-01-01  stock
# 000011.XSHE         深物业A   SWYA 1992-03-30 2200-01-01  stock
# 000012.XSHE          南玻A    NBA 1992-02-28 2200-01-01  stock
# 000014.XSHE         沙河股份   SHGF 1992-06-02 2200-01-01  stock
# 000016.XSHE         深康佳A   SKJA 1992-03-27 2200-01-01  stock
# 000017.XSHE         深中华A   SZHA 1992-03-31 2200-01-01  stock
# ...

# %%
list_stocks_code = df_stocks_info.index.tolist()
df = get_fundamentals(query(valuation).filter(
        # 这里不能使用 in 操作, 要使用in_()函数
        valuation.code.in_(list_stocks_code)
    ), date='2019-06-05')
df
# Out:
#             id         code   pe_ratio  turnover_ratio  pb_ratio  ps_ratio  \
# 0     35776561  300028.XSHE    -9.5057          0.0000    1.8705   63.3987
# 1     35775859  002260.XSHE    -5.3166          0.0000   -2.3693    1.2707
# 2     35776098  002499.XSHE    -1.4614          0.3498    4.5115 -109.1946
# 3     35777669  600462.XSHG    -3.0315          1.6184 -395.1271    0.4321
# 4     35775383  000693.XSHE    -0.3690          0.0003   -0.5367   20.2418
# 5     35776227  002629.XSHE    -1.4557          5.4689   44.7005    0.4378
# 6     35776358  002766.XSHE    -2.3014          4.8453    0.7607    0.7964
# 7     35775672  002072.XSHE    -3.9181          8.7622   -5.0440  -65.6808
# 8     35775922  002323.XSHE    -2.0433          0.0000    2.7580    9.6601
# 9     35778049  600891.XSHG    -0.2363          2.1609   -0.8680    0.5174
# 10    35775559  000953.XSHE    -4.0229          0.4233   -3.7965    5.1150
# ...

# %%
#data = pd.read_csv(r"C:\quanttime\data\finance\valuation\601318.XSHG.csv")
#data.columns = ['Unnamed: 0', 'id', 'day', 'code', 'pe_ratio', 'turnover_ratio','pb_ratio', 'ps_ratio', 'pcf_ratio', 
#                'capitalization', 'market_cap', 'circulating_cap', 'circulating_market_cap', 'pe_ratio_lyr']
df_tmp = pd.DataFrame(data=[df.iloc[3619].values],index=pd.Index([df.index[-1]]),columns=df.columns)
record_columns = ['id', 'day', 'code', 'pe_ratio', 'turnover_ratio','pb_ratio', 'ps_ratio', 'pcf_ratio', 
                'capitalization', 'market_cap', 'circulating_cap', 'circulating_market_cap', 'pe_ratio_lyr']
df_tmp = df_tmp[record_columns]
df_tmp.to_csv(r"C:\quanttime\data\finance\valuation\601318.XSHG.csv",mode='a', header=None)

# %%
q = query(valuation).filter(valuation.code == "002932.XSHE")
df_valuation = get_fundamentals_continuously(q,end_date="2019-06-05",count=200).to_frame()
# Out:
# C:\Anaconda3\lib\site-packages\jqdatasdk\api.py:107: FutureWarning:
# Panel is deprecated and will be removed in a future version.
# The recommended way to represent these types of 3-dimensional data are with a MultiIndex on a DataFrame, via the Panel.to_frame() method
# Alternatively, you can use the xarray package http://xarray.pydata.org/en/stable/.
# Pandas provides a `.to_xarray()` method to help automate this conversion.
#
#   pan = df3.to_panel()

# %%
tmp = df_valuation.loc[("2018-08-07","002932.XSHE"):("2019-06-05","002932.XSHE")]
tmp['Unname:1']=0
record_columns = ['Unname:1','id', 'day.1', 'code.1', 'pe_ratio', 'turnover_ratio', 'pb_ratio',
                'ps_ratio', 'pcf_ratio', 'capitalization', 'market_cap', 'circulating_cap',
                'circulating_market_cap','pe_ratio_lyr']
tmp = tmp[record_columns]
#tmp.to_csv(r'C:\quanttime\data\finance\valuation\002932.XSHE.csv',index=False, mode='a', header=None)
tmp
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                         Unname:1        id       day.1       code.1  pe_ratio  \
# day        code
# 2018-08-07 002932.XSHE         0  17952969  2018-08-07  002932.XSHE   93.2805
# 2018-08-08 002932.XSHE         0  17966488  2018-08-08  002932.XSHE   83.9575
# 2018-08-09 002932.XSHE         0  17977019  2018-08-09  002932.XSHE   82.3512
# 2018-08-10 002932.XSHE         0  17990532  2018-08-10  002932.XSHE   82.1478
# 2018-08-13 002932.XSHE         0  18002308  2018-08-13  002932.XSHE   82.7375
# 2018-08-14 002932.XSHE         0  18015836  2018-08-14  002932.XSHE   84.7505
# 2018-08-15 002932.XSHE         0  18028907  2018-08-15  002932.XSHE   81.0092
# ...

# %%
df_future_all = get_all_securities(['futures'])
df_future_all
# Out:
#             display_name    name start_date   end_date     type
# A0501.XDCE        豆一0501   a0501 2003-07-15 2005-01-17  futures
# A0503.XDCE        豆一0503   a0503 2003-09-15 2005-03-14  futures
# A0505.XDCE        豆一0505   a0505 2003-11-17 2005-05-20  futures
# A0507.XDCE        豆一0507   a0507 2004-01-16 2005-07-14  futures
# A0509.XDCE        豆一0509   a0509 2004-03-15 2005-09-14  futures
# A0511.XDCE        豆一0511   a0511 2004-05-24 2005-11-14  futures
# A0601.XDCE        豆一0601   a0601 2004-07-15 2006-01-17  futures
# A0603.XDCE        豆一0603   a0603 2004-09-15 2006-03-14  futures
# A0605.XDCE        豆一0605   a0605 2004-11-15 2006-05-19  futures
# A0607.XDCE        豆一0607   a0607 2005-01-18 2006-07-14  futures
# A0609.XDCE        豆一0609   a0609 2005-03-15 2006-09-14  futures
# A0611.XDCE        豆一0611   a0611 2005-05-23 2006-11-14  futures
# A0701.XDCE        豆一0701   a0701 2005-07-15 2007-01-17  futures
# A0703.XDCE        豆一0703   a0703 2005-09-15 2007-03-14  futures
# ...

# %%
list_ccfx_IC = []
list_ccfx_IF = []
list_ccfx_IH = []
for future_index in df_future_all.index:
    if 'IC' in future_index:
        list_ccfx_IC.append(future_index)
    elif 'IF' in future_index:
        list_ccfx_IF.append(future_index)
    elif 'IH' in future_index:
        list_ccfx_IH.append(future_index)
# Out:
#             display_name    name start_date   end_date     type
# IC1505.CCFX    中证500股指期货  IC1505 2015-04-16 2015-05-15  futures
# IC1506.CCFX    中证500股指期货  IC1506 2015-04-16 2015-06-19  futures
# IC1507.CCFX    中证500股指期货  IC1507 2015-05-18 2015-07-17  futures
# IC1508.CCFX    中证500股指期货  IC1508 2015-06-23 2015-08-21  futures
# IC1509.CCFX    中证500股指期货  IC1509 2015-04-16 2015-09-18  futures
# IC1510.CCFX    中证500股指期货  IC1510 2015-08-24 2015-10-16  futures
# IC1511.CCFX    中证500股指期货  IC1511 2015-09-21 2015-11-20  futures
# IC1512.CCFX    中证500股指期货  IC1512 2015-04-16 2015-12-18  futures
# IC1601.CCFX    中证500股指期货  IC1601 2015-11-23 2016-01-15  futures
# IC1602.CCFX    中证500股指期货  IC1602 2015-12-21 2016-02-19  futures
# IC1603.CCFX    中证500股指期货  IC1603 2015-07-20 2016-03-18  futures
# IC1604.CCFX    中证500股指期货  IC1604 2016-02-22 2016-04-15  futures
# IC1605.CCFX    中证500股指期货  IC1605 2016-03-21 2016-05-20  futures
# IC1606.CCFX    中证500股指期货  IC1606 2015-10-19 2016-06-17  futures
# ...

# %%
df_ic = df_future_all.loc[list_ccfx_IC]
#df_ic["end_date"] = df_ic["end_date"].apply(pd.Timestamp)
df_ic = df_ic[df_ic["end_date"] < pd.Timestamp.today()]
df_ic
# Out:
#             display_name    name start_date   end_date     type
# IC1505.CCFX    中证500股指期货  IC1505 2015-04-16 2015-05-15  futures
# IC1506.CCFX    中证500股指期货  IC1506 2015-04-16 2015-06-19  futures
# IC1507.CCFX    中证500股指期货  IC1507 2015-05-18 2015-07-17  futures
# IC1508.CCFX    中证500股指期货  IC1508 2015-06-23 2015-08-21  futures
# IC1509.CCFX    中证500股指期货  IC1509 2015-04-16 2015-09-18  futures
# IC1510.CCFX    中证500股指期货  IC1510 2015-08-24 2015-10-16  futures
# IC1511.CCFX    中证500股指期货  IC1511 2015-09-21 2015-11-20  futures
# IC1512.CCFX    中证500股指期货  IC1512 2015-04-16 2015-12-18  futures
# IC1601.CCFX    中证500股指期货  IC1601 2015-11-23 2016-01-15  futures
# IC1602.CCFX    中证500股指期货  IC1602 2015-12-21 2016-02-19  futures
# IC1603.CCFX    中证500股指期货  IC1603 2015-07-20 2016-03-18  futures
# IC1604.CCFX    中证500股指期货  IC1604 2016-02-22 2016-04-15  futures
# IC1605.CCFX    中证500股指期货  IC1605 2016-03-21 2016-05-20  futures
# IC1606.CCFX    中证500股指期货  IC1606 2015-10-19 2016-06-17  futures
# ...

# %%
df_sett_price = get_extras('futures_sett_price',['IC1505.CCFX'],start_date="2015-04-16", end_date='2015-05-15')
df_positions = get_extras('futures_positions',['IC1505.CCFX'],start_date="2015-04-16", end_date='2015-05-15')
df_data = get_price('IC1505.CCFX', start_date="2015-04-16", end_date='2015-05-15')
df_data = pd.merge(df_data,df_sett_price,left_index=True,right_index=True)
df_data = pd.merge(df_data,df_positions,left_index=True,right_index=True,suffixes=('_sett_price','_positions'))

df_data
# Out:
#               open   close    high     low    volume         money  \
# 2015-04-16  7681.0  7707.8  7790.0  7480.2  116888.0  1.792859e+11
# 2015-04-17  7722.0  7758.2  7918.8  7631.2  114214.0  1.781400e+11
# 2015-04-20  7760.0  7622.2  7857.0  7582.0   98781.0  1.525416e+11
# 2015-04-21  7650.2  8140.4  8147.0  7640.2  132545.0  2.093753e+11
# 2015-04-22  8158.0  8189.8  8237.8  8104.4  121034.0  1.976369e+11
# 2015-04-23  8193.0  8265.6  8378.8  8160.4  132278.0  2.185364e+11
# 2015-04-24  8247.8  8327.2  8349.8  8123.8  126381.0  2.077878e+11
# 2015-04-27  8368.0  8347.2  8548.0  8292.0  125335.0  2.105637e+11
# 2015-04-28  8308.0  8147.0  8419.0  8011.6  164120.0  2.689237e+11
# 2015-04-29  8138.0  8302.2  8309.0  8079.0  134158.0  2.206065e+11
# 2015-04-30  8320.0  8338.8  8408.0  8291.2  120118.0  2.006602e+11
# 2015-05-04  8370.2  8347.2  8527.4  8202.4  101734.0  1.690824e+11
# 2015-05-05  8334.8  8145.0  8345.0  8090.0  109987.0  1.808120e+11
# ...

# %%
df_data = df_data.rename(columns={'IC1505.CCFX'+'sett_price':"sett_price"})
df_data
# Out:
#               open   close    high     low    volume         money  \
# 2015-04-16  7681.0  7707.8  7790.0  7480.2  116888.0  1.792859e+11
# 2015-04-17  7722.0  7758.2  7918.8  7631.2  114214.0  1.781400e+11
# 2015-04-20  7760.0  7622.2  7857.0  7582.0   98781.0  1.525416e+11
# 2015-04-21  7650.2  8140.4  8147.0  7640.2  132545.0  2.093753e+11
# 2015-04-22  8158.0  8189.8  8237.8  8104.4  121034.0  1.976369e+11
# 2015-04-23  8193.0  8265.6  8378.8  8160.4  132278.0  2.185364e+11
# 2015-04-24  8247.8  8327.2  8349.8  8123.8  126381.0  2.077878e+11
# 2015-04-27  8368.0  8347.2  8548.0  8292.0  125335.0  2.105637e+11
# 2015-04-28  8308.0  8147.0  8419.0  8011.6  164120.0  2.689237e+11
# 2015-04-29  8138.0  8302.2  8309.0  8079.0  134158.0  2.206065e+11
# 2015-04-30  8320.0  8338.8  8408.0  8291.2  120118.0  2.006602e+11
# 2015-05-04  8370.2  8347.2  8527.4  8202.4  101734.0  1.690824e+11
# 2015-05-05  8334.8  8145.0  8345.0  8090.0  109987.0  1.808120e+11
# ...

# %%
df_gz = get_price("511010.XSHG", start_date="2013-03-25", end_date="2019-06-17", frequency='daily')

# %%
ret_2013 = (df_gz.loc['2013-12-31',["close"]]["close"] - df_gz.loc["2013-03-25",["close"]]["close"])/ df_gz.loc["2013-03-25",["close"]]["close"]
ret_2014 = (df_gz.loc['2014-12-31',["close"]]["close"] - df_gz.loc["2014-01-02",["close"]]["close"])/ df_gz.loc["2014-01-02",["close"]]["close"]
ret_2015 = (df_gz.loc['2015-12-31',["close"]]["close"] - df_gz.loc["2015-01-05",["close"]]["close"])/ df_gz.loc["2015-01-05",["close"]]["close"]
ret_2016 = (df_gz.loc['2016-12-30',["close"]]["close"] - df_gz.loc["2016-01-04",["close"]]["close"])/ df_gz.loc["2016-01-04",["close"]]["close"]
ret_2017 = (df_gz.loc['2017-12-29',["close"]]["close"] - df_gz.loc["2017-01-03",["close"]]["close"])/ df_gz.loc["2017-01-03",["close"]]["close"]
ret_2018 = (df_gz.loc['2018-12-28',["close"]]["close"] - df_gz.loc["2018-01-02",["close"]]["close"])/ df_gz.loc["2018-01-02",["close"]]["close"]
print(ret_2013, ret_2014, ret_2015, ret_2016, ret_2017, ret_2018)
(1+ret_2014)*(1+ret_2015)*(1+ret_2016)*(1+ret_2017)*(1+ret_2018)
# Out:
# -0.028782911482620275 0.07587611976349748 0.07328154770628756 0.01108625176932559 -0.012012717222442992 0.06458181154127107
# 1.2279891578542437

# %%
df_zq = get_price("399975.XSHE",start_date="2007-07-25", end_date="2019-06-21", frequency='daily')

# %%
df_zq.dropna()
# Out:
#                open    close     high      low        volume         money
# 2015-05-19  1518.04  1632.28  1659.57  1518.04  3.772612e+09  9.309065e+10
# 2015-05-20  1637.58  1604.66  1637.58  1602.00  2.828233e+09  7.147268e+10
# 2015-05-21  1603.09  1601.81  1610.02  1582.24  1.858109e+09  4.617736e+10
# 2015-05-22  1619.44  1653.20  1681.65  1614.60  3.418169e+09  8.649188e+10
# 2015-05-25  1658.89  1700.70  1730.00  1658.89  3.803496e+09  9.765779e+10
# 2015-05-26  1710.75  1720.23  1735.71  1667.81  4.057747e+09  9.964947e+10
# 2015-05-27  1722.82  1716.63  1746.18  1705.79  3.367540e+09  8.518020e+10
# 2015-05-28  1713.73  1561.57  1717.02  1561.08  3.846429e+09  9.534386e+10
# 2015-05-29  1571.14  1544.43  1591.32  1516.40  2.814375e+09  6.608362e+10
# 2015-06-01  1545.85  1628.47  1650.87  1524.92  3.083108e+09  7.413112e+10
# 2015-06-02  1621.63  1622.80  1636.12  1595.51  2.506534e+09  6.052673e+10
# ...

# %%
index_sz50_1 = get_price("000016.XSHG",start_date="2005-01-04",end_date="2019-06-21",frequency='daily',fq='pre')
index_sz50_2 = get_price("000016.XSHG",start_date="2005-01-04",end_date="2019-06-21",frequency='daily',fq=None)
index_sz50_3 = get_price("000016.XSHG",start_date="2005-01-04",end_date="2019-06-21",frequency='daily',fq='post')

# %%
print(index_sz50_1.tail(5))
print(index_sz50_2.tail(5))
print(index_sz50_3.tail(5))
# Out:
#                open    close     high      low        volume         money
# 2019-06-17  2785.47  2793.70  2813.45  2785.47  2.047785e+09  2.917243e+10
# 2019-06-18  2800.83  2806.45  2809.87  2785.38  2.167640e+09  2.883370e+10
# 2019-06-19  2872.07  2842.74  2879.23  2842.42  4.116011e+09  6.170081e+10
# 2019-06-20  2847.32  2942.63  2954.03  2846.44  5.736037e+09  8.726486e+10
# 2019-06-21  2939.65  2938.77  2958.23  2929.90  4.656020e+09  6.875173e+10
#                open    close     high      low        volume         money
# 2019-06-17  2785.47  2793.70  2813.45  2785.47  2.047785e+09  2.917243e+10
# 2019-06-18  2800.83  2806.45  2809.87  2785.38  2.167640e+09  2.883370e+10
# 2019-06-19  2872.07  2842.74  2879.23  2842.42  4.116011e+09  6.170081e+10
# 2019-06-20  2847.32  2942.63  2954.03  2846.44  5.736037e+09  8.726486e+10
# 2019-06-21  2939.65  2938.77  2958.23  2929.90  4.656020e+09  6.875173e+10
# ...

# %%
freq = '1M'
index_sz50_m = index_sz50_1[["open"]].resample(rule=freq).first()
index_sz50_m['high'] = index_sz50_1['high'].resample(rule=freq).max()
index_sz50_m['low'] = index_sz50_1['low'].resample(rule=freq).min()
index_sz50_m['close'] = index_sz50_1['close'].resample(rule=freq).last()
index_sz50_m['vol'] = index_sz50_1['volume'].resample(rule=freq).sum()
index_sz50_m['money'] = index_sz50_1['money'].resample(rule=freq).sum()

# %%
index_sz50_m['pcg'] = (index_sz50_m['close'] - index_sz50_m['open']) / index_sz50_m['open'] * 100
index_sz50_m['pcg'].describe()
#index_sz50_m['pcg'] = index_sz50_m['pcg'].map(lambda x: str(x) + "%")
# Out:
# count    174.00
# mean       1.02
# std        8.76
# min      -27.75
# 25%       -3.60
# 50%        1.37
# 75%        5.21
# max       33.29
# Name: pcg, dtype: float64

# %%
ah_info = r'C:\quanttime\data\AH_ratio\AH_code.csv'
columns_name = ["name", "a_code", "h_code", "s1", "s2", "s3", "s4", "s5", "s6", "s7", "s8"]
df_ah_code = pd.read_csv(ah_info, encoding="gbk", header=None, names=columns_name)
df_ah_code
# Out:
#       name  a_code  h_code     s1      s2       s3     s4      s5      s6  \
# 0     海螺水泥  600585     914  37.89  -1.76%   784.64  42.80  37.854  -2.62%
# 1     药明康德  603259    2359  62.68  -1.85%   368.21  67.65  59.832  -3.84%
# 2      万科A       2    2202  27.12  -3.18%  1504.15  27.50  24.322  -3.85%
# 3     招商银行  600036    3968  35.18  -1.59%  4367.53  37.05  32.768  -2.37%
# 4     马钢股份  600808     323   2.83  -1.74%    69.65   2.98   2.636  -0.67%
# 5     中国平安  601318    2318  84.84  -1.38%  8373.66  88.45  78.228  -2.70%
# 6     青岛啤酒  600600     168  42.37  -1.58%   123.20  43.55  38.517  -2.46%
# 7     宁沪高速  600377     177  10.30  -0.19%    48.03  10.40   9.198   1.96%
# 8     青岛银行    2948    3866   5.94  -1.00%    26.79   5.90   5.218  -6.35%
# 9     福耀玻璃  600660    3606  21.51  -2.23%   277.08  21.30  18.838  -4.05%
# 10    潍柴动力     338    2338  11.42  -2.64%   476.09  11.28   9.976  -2.25%
# 11    交通银行  601328    3328   5.58  -1.76%  1344.90   5.48   4.847  -1.44%
# ...

# %%
q=query(finance.STK_AH_PRICE_COMP).filter(finance.STK_AH_PRICE_COMP.a_code=='600660.XSHG',
                                         finance.STK_AH_PRICE_COMP.day>='2010-08-01').order_by(finance.STK_AH_PRICE_COMP.day).limit(100)
df=finance.run_query(q)
print(df)
# Out:
#         id         day  name       a_code h_code  a_price  h_price  \
# 0    95524  2015-03-31  福耀玻璃  600660.XSHG  03606    16.73   19.000
# 1   136738  2015-04-01  福耀玻璃  600660.XSHG  03606    16.75   18.820
# 2   102411  2015-04-02  福耀玻璃  600660.XSHG  03606    16.82   18.620
# 3    95070  2015-04-08  福耀玻璃  600660.XSHG  03606    16.99   18.720
# 4    33299  2015-04-09  福耀玻璃  600660.XSHG  03606    16.53   18.000
# 5   131609  2015-04-10  福耀玻璃  600660.XSHG  03606    16.82   18.800
# 6    20091  2015-04-13  福耀玻璃  600660.XSHG  03606    17.11   19.540
# 7    30867  2015-04-14  福耀玻璃  600660.XSHG  03606    18.15   19.340
# 8     9579  2015-04-15  福耀玻璃  600660.XSHG  03606    16.11   19.400
# 9   161381  2015-04-16  福耀玻璃  600660.XSHG  03606    16.22   19.520
# 10   91727  2015-04-17  福耀玻璃  600660.XSHG  03606    16.16   19.620
# 11   18044  2015-04-20  福耀玻璃  600660.XSHG  03606    15.47   19.420
# 12  100013  2015-04-21  福耀玻璃  600660.XSHG  03606    15.98   19.520
# ...

# %%
df_stocks_info = get_all_securities(types=['stock'])
# 提取还在上市的股票
df_stocks_info = df_stocks_info[df_stocks_info["end_date"] == "2200-01-01"]
list_stocks_code = df_stocks_info.index.tolist()
df_valuation_day = get_fundamentals(query(valuation).filter(valuation.code.in_(list_stocks_code)),date="2019-10-14")
df_valuation_day
# Out:
#             id         code   pe_ratio  turnover_ratio  pb_ratio  ps_ratio  \
# 0     39510783  000001.XSHE    12.4463          0.8027    1.4347    2.6250
# 1     39510784  000002.XSHE     8.3998          1.0711    1.9036    0.9260
# 2     39510785  000004.XSHE   -66.1783          0.7758   14.9068    4.9987
# 3     39510786  000005.XSHE    17.1121          1.0422    2.2336    5.4546
# 4     39510787  000006.XSHE    10.6501          0.4697    1.1481    2.9243
# 5     39510788  000007.XSHE   -17.3911          5.9358   17.6374   80.1285
# 6     39510789  000008.XSHE    30.1780          1.4889    1.3688    3.5972
# 7     39510790  000009.XSHE    51.7048          0.9156    2.2930    0.9199
# 8     39510791  000010.XSHE    -4.3938          0.3793    6.5082    3.9336
# 9     39510792  000011.XSHE     9.6561          0.4357    1.8155    2.1799
# 10    39510793  000012.XSHE    29.5541          0.8706    1.5084    1.4073
# ...

# %%
#print(len(list_stocks_code))
#print(len(df_valuation_day))
#set(list_stocks_code) - set(df_valuation_day["code"].tolist())
os.getcwd()
# Out:
# 'c:\\quanttime\\notebook'

# %%
q=query(opt.OPT_DAILY_PREOPEN.code,
        opt.OPT_DAILY_PREOPEN.trading_code,
        opt.OPT_DAILY_PREOPEN.name,
opt.OPT_DAILY_PREOPEN.exercise_date,).filter(opt.OPT_DAILY_PREOPEN.code=='10001313.XSHG').order_by(opt.OPT_DAILY_PREOPEN.date.desc()).limit(10)
df=opt.run_query(q)

# %%
all_trade_day = get_all_trade_days()
all_trade_day
# Out:
# array([datetime.date(2005, 1, 4), datetime.date(2005, 1, 5),
#        datetime.date(2005, 1, 6), ..., datetime.date(2020, 12, 29),
#        datetime.date(2020, 12, 30), datetime.date(2020, 12, 31)],
#       dtype=object)
